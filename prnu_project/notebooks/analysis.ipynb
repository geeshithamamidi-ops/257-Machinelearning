# %% [markdown]
# # PRNU project — analysis
#
# Load `results/group_*.json`, plot sweeps (JPEG, resize), reliability diagrams, and confusion matrices after running experiments from the `prnu_project` root.

# %%
import json
from pathlib import Path

ROOT = Path("..").resolve()
with open(ROOT / "results" / "group_A.json") as f:
    group_a = json.load(f)
group_a.keys()
